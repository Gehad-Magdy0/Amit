# %%
email = input("Enter your email: ")

# %%
print(email)
# Out:
# Amit_ml@gmail.edu”

# %%
email.count("@")
# Out:
# 1

# %%
if email.count("@") != 1:
    print("Invalid email")
else:
    after_at = email.split("@")[1]

# %%
if "." not in after_at:
    print("Invalid email")
else:
        username = email.split("@")[0]
        print(username)  

        domain = after_at.split(".")[0]
        print(domain)
# Out:
# Amit_ml
# gmail

# %%
    if email.endswith(".com"):
        print("Commercial Domain")
    elif email.endswith(".edu"):
        print("Educational Domain")
    else:
        print("Other Domain")
# Out:
# Other Domain

# %%
# Task 2

# %%
message = "###!!@mocleW EPGTQ!!!6789"
print(message)
# Out:
# ###!!@mocleW EPGTQ!!!6789

# %%
core = message.strip("#!@123456789")
print(core)
# Out:
# mocleW EPGTQ

# %%
print( core.split()[0][::-1])
# Out:
# Welcom

# %%
first = "Welcome"
second = "EPGTQ"

print(first + " " + second)
# Out:
# Welcome EPGTQ

# %%
# Task 3

# %%
message_2="&&&**$gnirtS PLIO!!@1234"
message_2
# Out:
# '&&&**$gnirtS PLIO!!@1234 '

# %%
core = message_2[6:18]
print(core)
# Out:
# gnirtS PLIO!

# %%
first = "gnirtS"
first = first[::-1]
print(first)
# Out:
# String

# %%
second = "PLIO"

# %%
second = second.replace("I", "E")
second = second.replace("O", "U")
print(second)
# Out:
# PLEU

# %%
result = first + " " + second
print(result)
# Out:
# String PLEU

# %%
# Task 4

# %%
message_3="##$$$@!yalpstcejorp EPUVT****9887 "
message_3
# Out:
# '##$$$@!yalpstcejorp EPUVT****9887 '

# %%
core=message_3[7:25]
core
# Out:
# 'yalpstcejorp EPUVT'

# %%
first="yalpstcejorp"
first = first[::-1]
first
# Out:
# 'projectsplay'

# %%
second="EPUVT"
second=second.replace("E","A")
second=second.replace("U","O")
second
# Out:
# 'APOVT'

# %%
result = first + " " + second
print(result)
# Out:
# projectsplay APOVT
